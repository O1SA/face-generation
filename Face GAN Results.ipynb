# %%
import tensorflow as tf
from tensorflow.python.tools import inspect_checkpoint as chkp
from matplotlib import pyplot
import helper

# %%
def display(sample):
    fig=pyplot.figure(figsize=(4, 4), dpi= 80)
    images_grid = helper.images_square_grid(sample, 'RGB')
    pyplot.axis('off')
    pyplot.imshow(images_grid, cmap=None)
    pyplot.show()

# %% [markdown]
# ## Face GAN

# %%
from face_gan import FaceGAN
n = FaceGAN()

# %% [markdown]
# After 1 epochs

# %%
samples = n.inference(5, 'output/face_1/face_gan.ckpt')
display(samples)

# %% [markdown]
# After 3 epochs

# %%
samples = n.inference(5, 'output/face_3/face_gan.ckpt')
display(samples)

# %% [markdown]
# After 4 epochs

# %%
samples = n.inference(5, 'output/face_4/face_gan.ckpt')
display(samples)

# %% [markdown]
# AWS after 3 epochs (deeper network)

# %%
samples = n.inference(5, 'output/aws_face/face_gan.ckpt')
display(samples)
